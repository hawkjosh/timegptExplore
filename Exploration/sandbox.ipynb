# %%
import os

from TokenUsage import showTokenUsage
from dotenv import load_dotenv
from GenerateData import generate_basic_data, generate_data_with_ex_vars
from nixtlats import TimeGPT

load_dotenv()
# Out:
# True

# %%
timegpt = TimeGPT(token=os.getenv("TIMEGPT_TOKEN"))
timegpt.validate_token()
# Out:
# INFO:nixtlats.timegpt:Happy Forecasting! :), If you have questions or need support, please email ops@nixtla.io
# True

# %%
showTokenUsage()
# Out:
# Token usage update timed out. There was either no update or the API is down.
#
# TOTAL USAGE: API Calls = 30 | Tokens = 166942 | Spent = 286.85

# %%
start = "2023-12-06"
end = "2024-03-04"
low = 75
high = 125

df_basic = generate_basic_data(start, end, low, high)
df_basic
# Out:
#     timestamp       value
# 0  2023-12-06   95.851100
# 1  2023-12-07  111.016225
# 2  2023-12-08   75.005719
# 3  2023-12-09   90.116629
# 4  2023-12-10   82.337795
# ..        ...         ...
# 85 2024-02-29  119.794311
# 86 2024-03-01   96.404559
# 87 2024-03-02  123.242002
# 88 2024-03-03  108.172075
# 89 2024-03-04  106.084786
#
# [90 rows x 2 columns]

# %%
df_basic_anomalies = timegpt.detect_anomalies(
    df_basic,
    time_col="timestamp",
    target_col="value",
)
df_basic_anomalies
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# INFO:nixtlats.timegpt:Inferred freq: D
# INFO:nixtlats.timegpt:Calling Anomaly Detector Endpoint...
#      timestamp  anomaly  TimeGPT-lo-99     TimeGPT  TimeGPT-hi-99
# 0   2024-01-09        0      58.652465   97.411652     136.170838
# 1   2024-01-10        0      59.382865   98.142052     136.901238
# 2   2024-01-11        0      61.361053  100.120239     138.879426
# 3   2024-01-12        0      62.737869  101.497055     140.256242
# 4   2024-01-13        0      62.357238  101.116425     139.875611
# 5   2024-01-14        0      61.870414  100.629601     139.388787
# 6   2024-01-15        0      59.919616   98.678802     137.437989
# 7   2024-01-16        0      65.394340  104.153526     142.912713
# 8   2024-01-17        0      64.841460  103.600647     142.359833
# 9   2024-01-18        0      65.852538  104.611725     143.370911
# ...

# %%
showTokenUsage()
# Out:
# << Current run: 1 call made | 370 tokens used | 1.00 spent >>
#
# TOTAL USAGE: API Calls = 31 | Tokens = 167312 | Spent = 287.85

# %%
df_basic_anomalies_lev75 = timegpt.detect_anomalies(
    df_basic, time_col="timestamp", target_col="value", level=75
)
df_basic_anomalies_lev75
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# INFO:nixtlats.timegpt:Inferred freq: D
# INFO:nixtlats.timegpt:Calling Anomaly Detector Endpoint...
#      timestamp  anomaly  TimeGPT-lo-75     TimeGPT  TimeGPT-hi-75
# 0   2024-01-09        0      80.102039   97.411652     114.721264
# 1   2024-01-10        0      80.832440   98.142052     115.451664
# 2   2024-01-11        0      82.810627  100.120239     117.429851
# 3   2024-01-12        0      84.187443  101.497055     118.806667
# 4   2024-01-13        1      83.806812  101.116425     118.426037
# 5   2024-01-14        0      83.319988  100.629601     117.939213
# 6   2024-01-15        1      81.369190   98.678802     115.988415
# 7   2024-01-16        0      86.843914  104.153526     121.463138
# 8   2024-01-17        0      86.291035  103.600647     120.910259
# 9   2024-01-18        0      87.302113  104.611725     121.921337
# ...

# %%
showTokenUsage()
# Out:
# << Current run: 1 call made | 370 tokens used | 1.00 spent >>
#
# TOTAL USAGE: API Calls = 32 | Tokens = 167682 | Spent = 288.85

# %%
df_basic_anomalies_lev50_plus_date_features = timegpt.detect_anomalies(
    df_basic, time_col="timestamp", target_col="value", level=50, date_features=True
)
df_basic_anomalies_lev50_plus_date_features
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# INFO:nixtlats.timegpt:Inferred freq: D
# INFO:nixtlats.timegpt:Calling Anomaly Detector Endpoint...
# INFO:nixtlats.timegpt:Using the following exogenous variables: year_2023, year_2024, month_1, month_2, month_3, month_12, day_1, day_2, day_3, day_4, day_5, day_6, day_7, day_8, day_9, day_10, day_11, day_12, day_13, day_14, day_15, day_16, day_17, day_18, day_19, day_20, day_21, day_22, day_23, day_24, day_25, day_26, day_27, day_28, day_29, day_30, day_31, weekday_0, weekday_1, weekday_2, weekday_3, weekday_4, weekday_5, weekday_6
#      timestamp  anomaly  TimeGPT-lo-50     TimeGPT  TimeGPT-hi-50
# 0   2024-01-09        1      84.523922   94.763239     105.002556
# 1   2024-01-10        0      85.026257   95.265574     105.504891
# 2   2024-01-11        1      86.881479   97.120796     107.360114
# 3   2024-01-12        1      88.164198   98.403515     108.642832
# ...

# %%
showTokenUsage()
# Out:
# << Current run: 1 call made | 4330 tokens used | 5.76 spent >>
#
# TOTAL USAGE: API Calls = 33 | Tokens = 172012 | Spent = 294.61

# %%
start = "2023-12-06"
end = "2024-03-04"
low_val = 75
high_val = 125
ex_vars_count = 2
ex_vars_low = 10
ex_vars_high = 20

df_ex_vars = generate_data_with_ex_vars(
    start, end, low_val, high_val, ex_vars_count, ex_vars_low, ex_vars_high
)
df_ex_vars
# Out:
#     timestamp       value   ex_var_1   ex_var_2
# 0  2023-12-06   95.851100  11.147460  16.297175
# 1  2023-12-07  111.016225  19.494893  12.101740
# 2  2023-12-08   75.005719  14.499121  17.527556
# 3  2023-12-09   90.116629  15.783896  10.665365
# 4  2023-12-10   82.337795  14.081368  12.603151
# ..        ...         ...        ...        ...
# 85 2024-02-29  119.794311  17.453344  13.226810
# 86 2024-03-01   96.404559  16.692329  16.707888
# 87 2024-03-02  123.242002  12.649196  14.508739
# 88 2024-03-03  108.172075  10.663348  13.821028
# 89 2024-03-04  106.084786  13.700842  14.108113
#
# [90 rows x 4 columns]

# %%
df_ex_vars_anomalies = timegpt.detect_anomalies(
    df_ex_vars,
    time_col="timestamp",
    target_col="value",
)
df_ex_vars_anomalies
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# INFO:nixtlats.timegpt:Inferred freq: D
# INFO:nixtlats.timegpt:Calling Anomaly Detector Endpoint...
# INFO:nixtlats.timegpt:Using the following exogenous variables: ex_var_1, ex_var_2
#      timestamp  anomaly  TimeGPT-lo-99     TimeGPT  TimeGPT-hi-99
# 0   2024-01-09        0      63.835697   98.827587     133.819477
# 1   2024-01-10        0      70.720385  105.712275     140.704165
# 2   2024-01-11        0      63.834346   98.826237     133.818127
# 3   2024-01-12        0      65.219568  100.211458     135.203349
# 4   2024-01-13        0      60.408860   95.400750     130.392640
# 5   2024-01-14        0      67.308651  102.300541     137.292431
# 6   2024-01-15        0      76.773871  111.765761     146.757651
# 7   2024-01-16        0      69.170417  104.162308     139.154198
# 8   2024-01-17        0      80.421551  115.413441     150.405332
# ...

# %%
showTokenUsage()
# Out:
# << Current run: 1 call made | 550 tokens used | 1.22 spent >>
#
# TOTAL USAGE: API Calls = 34 | Tokens = 172562 | Spent = 295.83

# %%
df_ex_vars_anomalies_lev75 = timegpt.detect_anomalies(
    df_ex_vars, time_col="timestamp", target_col="value", level=75
)
df_ex_vars_anomalies_lev75
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# INFO:nixtlats.timegpt:Inferred freq: D
# INFO:nixtlats.timegpt:Calling Anomaly Detector Endpoint...
# INFO:nixtlats.timegpt:Using the following exogenous variables: ex_var_1, ex_var_2
#      timestamp  anomaly  TimeGPT-lo-75     TimeGPT  TimeGPT-hi-75
# 0   2024-01-09        0      83.200426   98.827587     114.454748
# 1   2024-01-10        0      90.085114  105.712275     121.339436
# 2   2024-01-11        0      83.199076   98.826237     114.453398
# 3   2024-01-12        1      84.584297  100.211458     115.838619
# 4   2024-01-13        1      79.773589   95.400750     111.027911
# 5   2024-01-14        0      86.673380  102.300541     117.927702
# 6   2024-01-15        0      96.138600  111.765761     127.392922
# 7   2024-01-16        0      88.535147  104.162308     119.789469
# 8   2024-01-17        1      99.786280  115.413441     131.040602
# ...

# %%
showTokenUsage()
# Out:
# << Current run: 1 call made | 550 tokens used | 1.22 spent >>
#
# TOTAL USAGE: API Calls = 35 | Tokens = 173112 | Spent = 297.05

# %%
df_ex_vars_anomalies_lev50_plus_date_features = timegpt.detect_anomalies(
    df_ex_vars, time_col="timestamp", target_col="value", level=50, date_features=True
)
df_ex_vars_anomalies_lev50_plus_date_features
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# INFO:nixtlats.timegpt:Inferred freq: D
# INFO:nixtlats.timegpt:Calling Anomaly Detector Endpoint...
# INFO:nixtlats.timegpt:Using the following exogenous variables: ex_var_1, ex_var_2, year_2023, year_2024, month_1, month_2, month_3, month_12, day_1, day_2, day_3, day_4, day_5, day_6, day_7, day_8, day_9, day_10, day_11, day_12, day_13, day_14, day_15, day_16, day_17, day_18, day_19, day_20, day_21, day_22, day_23, day_24, day_25, day_26, day_27, day_28, day_29, day_30, day_31, weekday_0, weekday_1, weekday_2, weekday_3, weekday_4, weekday_5, weekday_6
#      timestamp  anomaly  TimeGPT-lo-50     TimeGPT  TimeGPT-hi-50
# 0   2024-01-09        1      88.672430   97.879491     107.086551
# 1   2024-01-10        1      93.405627  102.612688     111.819749
# 2   2024-01-11        1      88.254636   97.461697     106.668758
# 3   2024-01-12        1      87.599618   96.806679     106.013739
# ...

# %%
showTokenUsage()
# Out:
# << Current run: 1 call made | 4510 tokens used | 5.97 spent >>
#
# TOTAL USAGE: API Calls = 36 | Tokens = 177622 | Spent = 303.02
